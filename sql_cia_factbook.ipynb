# %% [markdown]
# ## SQL exploration
#
# This project aims to be a simple exploration of a database containing facts about countries, like the area of a country, the population, population growth and so on.
#
# We'll do this exploration here in jupyter using `ipython-sql`.

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///factbook.db

# %% [markdown]
# Let's see what tables we have in this database.

# %%
# %%sql
#
# SELECT *
#   FROM sqlite_master
# WHERE type='table';
# Out:
#  * sqlite:///factbook.db
# Done.
# [('table', 'sqlite_sequence', 'sqlite_sequence', 3, 'CREATE TABLE sqlite_sequence(name,seq)'),
#  ('table', 'facts', 'facts', 47, 'CREATE TABLE "facts" ("id" INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL, "code" varchar(255) NOT NULL, "name" varchar(255) NOT NULL, "area" integer, "a ... (4 characters truncated) ... land" integer, "area_water" integer, "population" integer, "population_growth" float, "birth_rate" float, "death_rate" float, "migration_rate" float)')]

# %% [markdown]
# Let's have, now, a first look at the facts table, printing its first 5 rows.

# %%
# %%sql
#
# SELECT *
#   FROM facts
# LIMIT 5;
# Out:
#  * sqlite:///factbook.db
# Done.
# [(1, 'af', 'Afghanistan', 652230, 652230, 0, 32564342, 2.32, 38.57, 13.89, 1.51),
#  (2, 'al', 'Albania', 28748, 27398, 1350, 3029278, 0.3, 12.92, 6.58, 3.3),
#  (3, 'ag', 'Algeria', 2381741, 2381741, 0, 39542166, 1.84, 23.67, 4.31, 0.92),
#  (4, 'an', 'Andorra', 468, 468, 0, 85580, 0.12, 8.13, 6.96, 0.0),
#  (5, 'ao', 'Angola', 1246700, 1246700, 0, 19625353, 2.78, 38.78, 11.49, 0.46)]

# %% [markdown]
# ## Population

# %% [markdown]
# What is the country with the most/least people in the world; and what about its growth.

# %%
# %%sql
#
# SELECT MIN(population), MAX(population), MIN(population_growth), MAX(population_growth)
#     FROM facts;
# Out:
#  * sqlite:///factbook.db
# Done.
# [(0, 7256490011, 0.0, 4.02)]

# %% [markdown]
# A bit weird. Let's investigate some more.

# %%
# %%sql
#
# SELECT *
#     FROM facts
#     WHERE population IN (SELECT MAX(population) FROM facts)
#     OR population IN (SELECT MIN(population) FROM facts);
# Out:
#  * sqlite:///factbook.db
# Done.
# [(250, 'ay', 'Antarctica', None, 280000, None, 0, None, None, None, None),
#  (261, 'xx', 'World', None, None, None, 7256490011, 1.08, 18.6, 7.8, None)]

# %% [markdown]
# Ok, so the World and Antarctica are included. But what about the maximum and minimum *without* these two?

# %%
# %%sql
#
# SELECT MIN(population), MAX(population), MIN(population_growth), MAX(population_growth)
#     FROM facts
# WHERE code NOT IN ('ay', 'xx');
# Out:
#  * sqlite:///factbook.db
# Done.
# [(48, 1367485388, 0.0, 4.02)]

# %% [markdown]
# Let's visualize these countries:

# %%
# %%sql
#
# SELECT *
#     FROM facts
# WHERE population IN (SELECT MAX(population) FROM facts WHERE code NOT IN ('ay', 'xx'))
# OR population IN (SELECT MIN(population) FROM facts WHERE code NOT IN ('ay', 'xx'))
# OR population_growth IN (SELECT MAX(population_growth) FROM facts WHERE code NOT IN ('ay', 'xx'))
# OR population_growth IN (SELECT MIN(population_growth) FROM facts WHERE code NOT IN ('ay', 'xx'));
# Out:
#  * sqlite:///factbook.db
# Done.
# [(37, 'ch', 'China', 9596960, 9326410, 270550, 1367485388, 0.45, 12.49, 7.53, 0.44),
#  (162, 'od', 'South Sudan', 644329, None, None, 12042910, 4.02, 36.91, 8.18, 11.47),
#  (190, 'vt', 'Holy See (Vatican City)', 0, 0, 0, 842, 0.0, None, None, None),
#  (200, 'ck', 'Cocos (Keeling) Islands', 14, 14, 0, 596, 0.0, None, None, None),
#  (207, 'gl', 'Greenland', 2166086, 2166086, None, 57733, 0.0, 14.48, 8.49, 5.98),
#  (238, 'pc', 'Pitcairn Islands', 47, 47, 0, 48, 0.0, None, None, None)]

# %% [markdown]
# ### Population growth percentiles

# %% [markdown]
# What we see here is that while the maximum and minimum for the population and the maximum for population growth are unique, the minimum for population growth is not unique: a bunch of countries have zero population growth.
#
# What is also surprising is how China's population growth is close to zero. This prompts us to investigate the percentiles of population growth.

# %%
# %%sql
#
# SELECT name AS 'Country',
#     population_growth AS 'Population Growth',
#     ROUND(PERCENT_RANK() OVER( ORDER BY population_growth ),2) AS 'Percent Rank'
# FROM facts WHERE population_growth <> 'None';
# Out:
#  * sqlite:///factbook.db
# Done.
# [('Holy See (Vatican City)', 0.0, 0.0),
#  ('Cocos (Keeling) Islands', 0.0, 0.0),
#  ('Greenland', 0.0, 0.0),
#  ('Pitcairn Islands', 0.0, 0.0),
#  ('Greece', 0.01, 0.02),
#  ('Norfolk Island', 0.01, 0.02),
#  ('Tokelau', 0.01, 0.02),
#  ('Falkland Islands (Islas Malvinas)', 0.01, 0.02),
#  ('Guyana', 0.02, 0.03),
#  ('Slovakia', 0.02, 0.03),
#  ('Tonga', 0.03, 0.04),
#  ('Niue', 0.03, 0.04),
#  ('Svalbard', 0.03, 0.04),
#  ('Russia', 0.04, 0.06),
#  ('Georgia', 0.08, 0.06),
#  ('Maldives', 0.08, 0.06),
#  ('Poland', 0.09, 0.07),
#  ('Portugal', 0.09, 0.07),
#  ('Andorra', 0.12, 0.08),
#  ('Monaco', 0.12, 0.08),
#  ('Bosnia and Herzegovina', 0.13, 0.09),
#  ('Croatia', 0.13, 0.09),
#  ('Trinidad and Tobago', 0.13, 0.09),
#  ('Korea, South', 0.14, 0.1),
#  ('Armenia', 0.15, 0.1),
#  ('Cuba', 0.15, 0.1),
#  ('Czech Republic', 0.16, 0.11),
#  ('Japan', 0.16, 0.11),
#  ('Syria', 0.16, 0.11),
#  ('Germany', 0.17, 0.12),
#  ('Belarus', 0.2, 0.13),
#  ('Macedonia', 0.2, 0.13),
#  ('Dominica', 0.21, 0.14),
#  ('Denmark', 0.22, 0.14),
#  ('Hungary', 0.22, 0.14),
#  ('Taiwan', 0.23, 0.15),
#  ('Gibraltar', 0.24, 0.15),
#  ('Saint Helena, Ascension, and Tristan da Cunha', 0.24, 0.15),
#  ('El Salvador', 0.25, 0.16),
#  ('European Union', 0.25, 0.16),
#  ('Slovenia', 0.26, 0.17),
#  ('Italy', 0.27, 0.17),
#  ('Uruguay', 0.27, 0.17),
#  ('Saint Vincent and the Grenadines', 0.28, 0.18),
#  ('Albania', 0.3, 0.19),
#  ('Romania', 0.3, 0.19),
#  ('American Samoa', 0.3, 0.19),
#  ('Barbados', 0.31, 0.2),
#  ('Malta', 0.31, 0.2),
#  ('Lesotho', 0.32, 0.21),
#  ('Wallis and Futuna', 0.33, 0.21),
#  ('Saint Lucia', 0.34, 0.22),
#  ('Thailand', 0.34, 0.22),
#  ('Guernsey', 0.34, 0.22),
#  ('Palau', 0.38, 0.23),
#  ('Hong Kong', 0.38, 0.23),
#  ('Finland', 0.4, 0.24),
#  ('Netherlands', 0.41, 0.24),
#  ('Montenegro', 0.42, 0.25),
#  ('France', 0.43, 0.25),
#  ('Curacao', 0.43, 0.25),
#  ('China', 0.45, 0.26),
#  ('Micronesia, Federated States of', 0.46, 0.26),
#  ('Serbia', 0.46, 0.26),
#  ('Grenada', 0.48, 0.27),
#  ('Bermuda', 0.5, 0.28),
#  ('Montserrat', 0.5, 0.28),
#  ('Faroe Islands', 0.51, 0.29),
#  ('Korea, North', 0.53, 0.29),
#  ('United Kingdom', 0.54, 0.29),
#  ('Guam', 0.54, 0.29),
#  ('Austria', 0.55, 0.3),
#  ('Estonia', 0.55, 0.3),
#  ('Nauru', 0.55, 0.3),
#  ('Bulgaria', 0.58, 0.31),
#  ('Samoa', 0.58, 0.31),
#  ('Namibia', 0.59, 0.32),
#  ('Virgin Islands', 0.59, 0.32),
#  ('Ukraine', 0.6, 0.33),
#  ('Puerto Rico', 0.6, 0.33),
#  ('Mauritius', 0.64, 0.34),
#  ('Fiji', 0.67, 0.34),
#  ('Jamaica', 0.68, 0.35),
#  ('Switzerland', 0.71, 0.35),
#  ('Canada', 0.75, 0.36),
#  ('Belgium', 0.76, 0.36),
#  ('Saint Kitts and Nevis', 0.76, 0.36),
#  ('Isle of Man', 0.76, 0.36),
#  ('Brazil', 0.77, 0.37),
#  ('United States', 0.78, 0.38),
#  ('Sweden', 0.8, 0.38),
#  ('Macau', 0.8, 0.38),
#  ('Jersey', 0.8, 0.38),
#  ('Chile', 0.82, 0.4),
#  ('New Zealand', 0.82, 0.4),
#  ('San Marino', 0.82, 0.4),
#  ('Tuvalu', 0.82, 0.4),
#  ('Jordan', 0.83, 0.41),
#  ('Seychelles', 0.83, 0.41),
#  ('Liechtenstein', 0.84, 0.42),
#  ('Sri Lanka', 0.84, 0.42),
#  ('Bahamas, The', 0.85, 0.43),
#  ('Lebanon', 0.86, 0.43),
#  ('Spain', 0.89, 0.44),
#  ('Tunisia', 0.89, 0.44),
#  ('Indonesia', 0.92, 0.45),
#  ('Argentina', 0.93, 0.45),
#  ('Uzbekistan', 0.93, 0.45),
#  ('French Polynesia', 0.94, 0.46),
#  ('Azerbaijan', 0.96, 0.46),
#  ('Peru', 0.97, 0.47),
#  ('Vietnam', 0.97, 0.47),
#  ('Morocco', 1.0, 0.48),
#  ('Nicaragua', 1.0, 0.48),
#  ('Burma', 1.01, 0.49),
#  ('Moldova', 1.03, 0.49),
#  ('Colombia', 1.04, 0.49),
#  ('Lithuania', 1.04, 0.49),
#  ('Latvia', 1.06, 0.5),
#  ('Australia', 1.07, 0.51),
#  ('Suriname', 1.08, 0.51),
#  ('Saint Pierre and Miquelon', 1.08, 0.51),
#  ('World', 1.08, 0.51),
#  ('Bhutan', 1.11, 0.52),
#  ('Kyrgyzstan', 1.11, 0.52),
#  ('Swaziland', 1.11, 0.52),
#  ('Christmas Island', 1.11, 0.52),
#  ('Norway', 1.13, 0.54),
#  ('Kazakhstan', 1.14, 0.54),
#  ('Turkmenistan', 1.14, 0.54),
#  ('Kiribati', 1.15, 0.55),
#  ('Paraguay', 1.16, 0.56),
#  ('Haiti', 1.17, 0.56),
#  ('Mexico', 1.18, 0.57),
#  ('Iran', 1.2, 0.57),
#  ('Botswana', 1.21, 0.57),
#  ('Iceland', 1.21, 0.57),
#  ('Costa Rica', 1.22, 0.58),
#  ('India', 1.22, 0.58),
#  ('Dominican Republic', 1.23, 0.59),
#  ('Antigua and Barbuda', 1.24, 0.6),
#  ('Ireland', 1.25, 0.6),
#  ('Turkey', 1.26, 0.6),
#  ('Mongolia', 1.31, 0.61),
#  ('Panama', 1.32, 0.61),
#  ('South Africa', 1.33, 0.62),
#  ('Aruba', 1.33, 0.62),
#  ('Ecuador', 1.35, 0.63),
#  ('Cabo Verde', 1.36, 0.63),
#  ('New Caledonia', 1.38, 0.63),
#  ('Venezuela', 1.39, 0.64),
#  ('Cyprus', 1.43, 0.64),
#  ('Malaysia', 1.44, 0.65),
#  ('Pakistan', 1.46, 0.65),
#  ('Saudi Arabia', 1.46, 0.65),
#  ('Sint Maarten', 1.51, 0.66),
#  ('Laos', 1.55, 0.66),
#  ('Bolivia', 1.56, 0.67),
#  ('Israel', 1.56, 0.67),
#  ('Cambodia', 1.58, 0.68),
#  ('Bangladesh', 1.6, 0.68),
#  ('Philippines', 1.61, 0.69),
#  ('Brunei', 1.62, 0.69),
#  ('Kuwait', 1.62, 0.69),
#  ('Marshall Islands', 1.66, 0.7),
#  ('Honduras', 1.68, 0.7),
#  ('Tajikistan', 1.71, 0.71),
#  ('Sudan', 1.72, 0.71),
#  ('Comoros', 1.77, 0.71),
#  ('Papua New Guinea', 1.78, 0.72),
#  ('Egypt', 1.79, 0.72),
#  ('Nepal', 1.79, 0.72),
#  ('Guatemala', 1.82, 0.73),
#  ('Somalia', 1.83, 0.74),
#  ('Algeria', 1.84, 0.74),
#  ('Sao Tome and Principe', 1.84, 0.74),
#  ('Belize', 1.87, 0.75),
#  ('Chad', 1.89, 0.75),
#  ('Singapore', 1.89, 0.75),
#  ("Cote d'Ivoire", 1.91, 0.76),
#  ('Guinea-Bissau', 1.91, 0.76),
#  ('Gabon', 1.93, 0.77),
#  ('Kenya', 1.93, 0.77),
#  ('Vanuatu', 1.95, 0.78),
#  ('West Bank', 1.95, 0.78),
#  ('Congo, Republic of the', 2.0, 0.79),
#  ('Solomon Islands', 2.02, 0.79),
#  ('Anguilla', 2.03, 0.8),
#  ('Oman', 2.07, 0.8),
#  ('Cayman Islands', 2.1, 0.8),
#  ('Central African Republic', 2.13, 0.81),
#  ('Luxembourg', 2.13, 0.81),
#  ('Gambia, The', 2.16, 0.82),
#  ('Ghana', 2.18, 0.82),
#  ('Northern Mariana Islands', 2.18, 0.82),
#  ('Djibouti', 2.2, 0.83),
#  ('Zimbabwe', 2.21, 0.83),
#  ('Libya', 2.23, 0.84),
#  ('Mauritania', 2.23, 0.84),
#  ('Eritrea', 2.25, 0.85),
#  ('Turks and Caicos Islands', 2.3, 0.85),
#  ('Afghanistan', 2.32, 0.86),
#  ('British Virgin Islands', 2.32, 0.86),
#  ('Sierra Leone', 2.35, 0.86),
#  ('Bahrain', 2.41, 0.87),
#  ('Timor-Leste', 2.42, 0.87),
#  ('Congo, Democratic Republic of the', 2.45, 0.88),
#  ('Mozambique', 2.45, 0.88),
#  ('Nigeria', 2.45, 0.88),
#  ('Senegal', 2.45, 0.88),
#  ('Liberia', 2.47, 0.89),
#  ('Yemen', 2.47, 0.89),
#  ('Equatorial Guinea', 2.51, 0.9),
#  ('Rwanda', 2.56, 0.91),
#  ('Madagascar', 2.58, 0.91),
#  ('United Arab Emirates', 2.58, 0.91),
#  ('Cameroon', 2.59, 0.92),
#  ('Guinea', 2.63, 0.92),
#  ('Togo', 2.69, 0.93),
#  ('Angola', 2.78, 0.93),
#  ('Benin', 2.78, 0.93),
#  ('Tanzania', 2.79, 0.94),
#  ('Gaza Strip', 2.81, 0.94),
#  ('Western Sahara', 2.82, 0.95),
#  ('Zambia', 2.88, 0.95),
#  ('Ethiopia', 2.89, 0.96),
#  ('Iraq', 2.93, 0.96),
#  ('Cook Islands', 2.95, 0.97),
#  ('Mali', 2.98, 0.97),
#  ('Burkina Faso', 3.03, 0.97),
#  ('Qatar', 3.07, 0.98),
#  ('Uganda', 3.24, 0.98),
#  ('Niger', 3.25, 0.99),
#  ('Burundi', 3.28, 0.99),
#  ('Malawi', 3.32, 1.0),
#  ('South Sudan', 4.02, 1.0)]

# %% [markdown]
# For some reason some countries have `None` population_growth -- I suppose its just missing information. So I have to exclude those from the percentile calculation.
#
# With this closer inspection we see that China's population growth is quite typical (if not a bit high) for developed nations.

# %% [markdown]
# ### Population and death

# %% [markdown]
# Let's do some investigation with the `death_rate` column. More specifically, let's see the average and the percentiles.

# %%
# %%sql
#
# SELECT MIN(death_rate), MAX(death_rate), AVG(death_rate)
#     FROM facts;
# Out:
#  * sqlite:///factbook.db
# Done.
# [(1.53, 14.89, 7.8212719298245625)]

# %%
# %%sql
#
# SELECT *
#     FROM facts
# WHERE death_rate IN (SELECT MAX(death_rate) FROM facts)
# OR death_rate IN (SELECT MIN(death_rate) FROM facts);
# Out:
#  * sqlite:///factbook.db
# Done.
# [(98, 'lt', 'Lesotho', 30355, 30355, 0, 1947701, 0.32, 25.47, 14.89, 7.36),
#  (141, 'qa', 'Qatar', 11586, 11586, 0, 2194817, 3.07, 9.84, 1.53, 22.39)]

# %%
# %%sql
#
# SELECT AVG(death_rate)
#     FROM facts
# Out:
#  * sqlite:///factbook.db
# Done.
# [(7.8212719298245625,)]

# %% [markdown]
# Below avarage death rates:

# %%
# %%sql
#
# SELECT *
#     FROM facts
# WHERE death_rate <= (SELECT AVG(death_rate) FROM facts)
# ORDER BY death_rate;
# Out:
#  * sqlite:///factbook.db
# Done.
# [(141, 'qa', 'Qatar', 11586, 11586, 0, 2194817, 3.07, 9.84, 1.53, 22.39),
#  (184, 'ae', 'United Arab Emirates', 83600, 83600, 0, 5779760, 2.58, 15.43, 1.97, 12.36),
#  (93, 'ku', 'Kuwait', 17818, 17818, 0, 2788534, 1.62, 19.91, 2.18, 1.58),
#  (13, 'ba', 'Bahrain', 760, 760, 0, 1346613, 2.41, 13.66, 2.69, 13.09),
#  (251, 'gz', 'Gaza Strip', 360, 360, 0, 1869055, 2.81, 31.11, 3.04, 0.0),
#  (241, 'tk', 'Turks and Caicos Islands', 948, 948, 0, 50280, 2.3, 16.13, 3.1, 9.94),
#  (151, 'sa', 'Saudi Arabia', 2149690, 2149690, 0, 27752316, 1.46, 18.51, 3.33, 0.55),
#  (131, 'mu', 'Oman', 309500, 309500, 0, 3286936, 2.07, 24.44, 3.36, 0.43),
#  (156, 'sn', 'Singapore', 697, 687, 10, 5674472, 1.89, 8.27, 3.43, 14.05),
#  (254, 'we', 'West Bank', 5860, 5640, 220, 2785366, 1.95, 22.99, 3.5, 0.0),
#  (25, 'bx', 'Brunei', 5765, 5265, 500, 429646, 1.62, 17.32, 3.52, 2.43),
#  (100, 'ly', 'Libya', 1759540, 1759540, 0, 6411776, 2.23, 18.03, 3.58, 7.8),
#  (245, 'cq', 'Northern Mariana Islands', 464, 464, 0, 52344, 2.18, 18.32, 3.71, 7.16),
#  (80, 'iz', 'Iraq', 438317, 437367, 950, 37056169, 2.93, 31.45, 3.77, 1.62),
#  (86, 'jo', 'Jordan', 89342, 88802, 540, 8117564, 0.83, 25.37, 3.79, 13.24),
#  (159, 'bp', 'Solomon Islands', 28896, 27986, 910, 622469, 2.02, 25.77, 3.85, 1.75),
#  (108, 'mv', 'Maldives', 298, 298, 0, 393253, 0.08, 15.75, 3.89, 12.68),
#  (170, 'sy', 'Syria', 185180, 183630, 1550, 17064854, 0.16, 22.17, 4.0, 19.79),
#  (189, 'nh', 'Vanuatu', 12189, 12189, 0, 272264, 1.95, 25.04, 4.09, 1.47),
#  (111, 'rm', 'Marshall Islands', 181, 181, 0, 72191, 1.66, 25.6, 4.21, 4.83),
#  (205, 'mc', 'Macau', 28, 28, 0, 592731, 0.8, 8.88, 4.22, 3.37),
#  (115, 'fm', 'Micronesia, Federated States of', 702, 702, 0, 105216, 0.46, 20.54, 4.23, 20.93),
#  (3, 'ag', 'Algeria', 2381741, 2381741, 0, 39542166, 1.84, 23.67, 4.31, 0.92),
#  (218, 'sk', 'Sint Maarten', 34, 34, 0, 39689, 1.51, 13.0, 4.51, 6.63),
#  (42, 'cs', 'Costa Rica', 51100, 51060, 40, 4814144, 1.22, 15.91, 4.55, 0.83),
#  (51, 'dr', 'Dominican Republic', 48670, 48320, 350, 10478756, 1.23, 18.73, 4.55, 1.91),
#  (226, 'av', 'Anguilla', 91, 91, 0, 16418, 2.03, 12.67, 4.57, 12.18),
#  (136, 'pa', 'Paraguay', 406752, 397302, 9450, 6783272, 1.16, 16.37, 4.68, 0.07),
#  (242, 'aq', 'American Samoa', 199, 199, 0, 54343, 0.3, 22.89, 4.75, 21.13),
#  (53, 'eg', 'Egypt', 1001450, 995450, 6000, 88487396, 1.79, 22.9, 4.77, 0.19),
#  (69, 'gt', 'Guatemala', 108889, 107159, 1730, 14918999, 1.82, 24.89, 4.77, 1.97),
#  (120, 'mo', 'Morocco', 446550, 446300, 250, 33322699, 1.0, 18.2, 4.81, 3.36),
#  (134, 'pm', 'Panama', 75420, 74340, 1080, 3657024, 1.32, 18.32, 4.81, 0.28),
#  (176, 'tn', 'Tonga', 747, 717, 30, 106501, 0.03, 23.0, 4.85, 17.84),
#  (97, 'le', 'Lebanon', 10400, 10230, 170, 6184701, 0.86, 14.59, 4.88, 1.1),
#  (232, 'fk', 'Falkland Islands (Islas Malvinas)', 12173, 12173, 0, 3361, 0.01, 10.9, 4.9, None),
#  (229, 'vi', 'British Virgin Islands', 151, 151, 0, 33454, 2.32, 10.91, 4.99, 17.28),
#  (209, 'fp', 'French Polynesia', 4167, 3827, 340, 282703, 0.94, 15.22, 5.02, 0.84),
#  (107, 'my', 'Malaysia', 329847, 328657, 1190, 30513848, 1.44, 19.71, 5.03, 0.33),
#  (52, 'ec', 'Ecuador', 283561, 276841, 6720, 15868396, 1.35, 18.51, 5.06, 0.0),
#  (215, 'wf', 'Wallis and Futuna', 142, 142, 0, 15613, 0.33, 13.45, 5.06, 5.06),
#  (127, 'nu', 'Nicaragua', 130370, 119990, 10380, 5907881, 1.0, 18.03, 5.08, 3.0),
#  (243, 'gq', 'Guam', 544, 544, 0, 161785, 0.54, 16.82, 5.12, 6.34),
#  (82, 'is', 'Israel', 20770, 20330, 440, 8049314, 1.56, 18.48, 5.15, 2.24),
#  (74, 'ho', 'Honduras', 112090, 111890, 200, 8746673, 1.68, 23.14, 5.17, 1.16),
#  (114, 'mx', 'Mexico', 1964375, 1943945, 20430, 121736809, 1.18, 18.78, 5.26, 1.68),
#  (188, 'uz', 'Uzbekistan', 447400, 425400, 22000, 29199942, 0.93, 17.0, 5.3, 2.37),
#  (191, 've', 'Venezuela', 912050, 882050, 30000, 29275460, 1.39, 19.16, 5.31, 0.0),
#  (148, 'ws', 'Samoa', 2831, 2821, 10, 197773, 0.58, 20.87, 5.32, 9.78),
#  (38, 'co', 'Colombia', 1138910, 1038700, 100210, 46736728, 1.04, 16.47, 5.4, 0.64),
#  (211, 'nc', 'New Caledonia', 18575, 18275, 300, 271615, 1.38, 15.33, 5.52, 4.01),
#  (230, 'cj', 'Cayman Islands', 264, 264, 0, 56092, 2.1, 12.11, 5.53, 14.4),
#  (14, 'bg', 'Bangladesh', 148460, 130170, 18290, 168957745, 1.6, 21.14, 5.61, 0.46),
#  (6, 'ac', 'Antigua and Barbuda', 442, 442, 0, 92436, 1.24, 15.85, 5.69, 2.21),
#  (54, 'es', 'El Salvador', 21041, 20721, 320, 6141350, 0.25, 16.46, 5.69, 8.28),
#  (123, 'nr', 'Nauru', 21, 21, 0, 9540, 0.55, 24.95, 5.87, 13.63),
#  (179, 'tu', 'Turkey', 783562, 769632, 13930, 79414269, 1.26, 16.33, 5.88, 2.16),
#  (192, 'vm', 'Vietnam', 331210, 310070, 21140, 94348835, 0.97, 15.96, 5.93, 0.3),
#  (79, 'ir', 'Iran', 1648195, 1531595, 116600, 81824270, 1.2, 17.99, 5.94, 0.07),
#  (18, 'bh', 'Belize', 22966, 22806, 160, 347369, 1.87, 24.68, 5.97, 0.0),
#  (178, 'ts', 'Tunisia', 163610, 155360, 8250, 11037225, 0.89, 16.64, 5.98, 1.73),
#  (36, 'ci', 'Chile', 756102, 743812, 12290, 17508260, 0.82, 13.83, 6.0, 0.34),
#  (137, 'pe', 'Peru', 1285216, 1279996, 5220, 30444999, 0.97, 18.28, 6.01, 2.53),
#  (59, 'fj', 'Fiji', 18274, 18274, 0, 909389, 0.67, 19.43, 6.04, 6.75),
#  (174, 'tt', 'Timor-Leste', 14874, 14874, 0, 1231116, 2.42, 34.16, 6.1, 3.86),
#  (33, 'cv', 'Cabo Verde', 4033, 4033, 0, 545993, 1.36, 20.33, 6.11, 0.63),
#  (138, 'rp', 'Philippines', 300000, 298170, 1830, 100998376, 1.61, 24.27, 6.11, 2.09),
#  (164, 'ce', 'Sri Lanka', 65610, 64630, 980, 22053488, 0.84, 15.85, 6.11, 1.35),
#  (166, 'ns', 'Suriname', 163820, 156000, 7820, 579633, 1.08, 16.34, 6.13, 0.56),
#  (180, 'tx', 'Turkmenistan', 488100, 469930, 18170, 5231422, 1.14, 19.4, 6.13, 1.84),
#  (171, 'ti', 'Tajikistan', 144100, 141510, 2590, 8191958, 1.71, 24.38, 6.18, 1.15),
#  (76, 'ic', 'Iceland', 103000, 100250, 2750, 331918, 1.21, 13.91, 6.28, 4.43),
#  (193, 'ym', 'Yemen', 527968, 527968, 0, 26737317, 2.47, 29.98, 6.28, 1.0),
#  (237, 'mh', 'Montserrat', 102, 102, 0, 5241, 0.5, 11.26, 6.3, 0.0),
#  (118, 'mg', 'Mongolia', 1564116, 1553556, 10560, 2992908, 1.31, 20.25, 6.35, 0.84),
#  (78, 'id', 'Indonesia', 1904569, 1811569, 93000, 255993674, 0.92, 16.72, 6.37, 1.16),
#  (81, 'ei', 'Ireland', 70273, 68883, 1390, 4892305, 1.25, 14.84, 6.48, 4.09),
#  (132, 'pk', 'Pakistan', 796095, 770875, 25220, 199085847, 1.46, 22.58, 6.49, 1.54),
#  (21, 'bl', 'Bolivia', 1098581, 1083301, 15280, 10800882, 1.56, 22.76, 6.52, 0.62),
#  (135, 'pp', 'Papua New Guinea', 462840, 452860, 9980, 6672429, 1.78, 24.38, 6.53, 0.0),
#  (124, 'np', 'Nepal', 147181, 143351, 3830, 31551305, 1.79, 20.64, 6.56, 3.86),
#  (2, 'al', 'Albania', 28748, 27398, 1350, 3029278, 0.3, 12.92, 6.58, 3.3),
#  (24, 'br', 'Brazil', 8515770, 8358140, 157630, 204259812, 0.77, 14.46, 6.58, 0.14),
#  (46, 'cy', 'Cyprus', 9251, 9241, 10, 1189197, 1.43, 11.41, 6.62, 9.48),
#  (94, 'kg', 'Kyrgyzstan', 199951, 191801, 8150, 5664939, 1.11, 22.98, 6.65, 5.22),
#  (20, 'bt', 'Bhutan', 38394, 38394, 0, 741919, 1.11, 17.78, 6.69, 0.0),
#  (84, 'jm', 'Jamaica', 10991, 10831, 160, 2950210, 0.68, 18.16, 6.7, 4.66),
#  (91, 'ks', 'Korea, South', 99720, 96920, 2800, 49115196, 0.14, 8.19, 6.75, 0.0),
#  (105, 'ma', 'Madagascar', 587041, 581540, 5501, 23812681, 2.58, 32.61, 6.81, 0.0),
#  (88, 'ke', 'Kenya', 580367, 569140, 11227, 45925301, 1.93, 26.4, 6.89, 0.22),
#  (154, 'se', 'Seychelles', 455, 455, 0, 92430, 0.83, 14.19, 6.89, 1.0),
#  (113, 'mp', 'Mauritius', 2040, 2030, 10, 1339827, 0.64, 13.29, 6.91, 0.0),
#  (4, 'an', 'Andorra', 468, 468, 0, 85580, 0.12, 8.13, 6.96, 0.0),
#  (12, 'bf', 'Bahamas, The', 13880, 10010, 3870, 324597, 0.85, 15.5, 7.05, 0.0),
#  (11, 'aj', 'Azerbaijan', 86600, 82629, 3971, 9780780, 0.96, 16.64, 7.07, 0.0),
#  (204, 'hk', 'Hong Kong', 1108, 1073, 35, 7141106, 0.38, 9.23, 7.07, 1.68),
#  (145, 'sc', 'Saint Kitts and Nevis', 261, 261, 0, 51936, 0.76, 13.5, 7.09, 1.21),
#  (196, 'tw', 'Taiwan', 35980, 32260, 3720, 23415126, 0.23, 8.47, 7.11, 0.89),
#  (89, 'kr', 'Kiribati', 811, 811, 0, 105711, 1.15, 21.46, 7.12, 2.87),
#  (101, 'ls', 'Liechtenstein', 160, 160, 0, 37624, 0.84, 10.45, 7.12, 5.08),
#  (9, 'as', 'Australia', 7741220, 7682300, 58920, 22751014, 1.07, 12.15, 7.14, 5.65),
#  (63, 'ga', 'Gambia, The', 11300, 10120, 1180, 1967709, 2.16, 30.86, 7.15, 2.12),
#  (147, 'vc', 'Saint Vincent and the Grenadines', 389, 389, 0, 102627, 0.28, 13.57, 7.18, 9.17),
#  (66, 'gh', 'Ghana', 238533, 227533, 11000, 26327649, 2.18, 31.09, 7.22, 2.02),
#  (103, 'lu', 'Luxembourg', 2586, 2586, 0, 570252, 2.13, 11.37, 7.24, 17.16),
#  (150, 'tp', 'Sao Tome and Principe', 964, 964, 0, 194006, 1.84, 34.23, 7.24, 8.63),
#  (175, 'to', 'Togo', 56785, 54385, 2400, 7552318, 2.69, 34.13, 7.26, 0.0),
#  (72, 'gy', 'Guyana', 214969, 196849, 18120, 735222, 0.02, 15.59, 7.32, 8.06),
#  (77, 'in', 'India', 3287263, 2973193, 314070, 1251695584, 1.22, 19.55, 7.32, 0.04),
#  (7, 'ar', 'Argentina', 2780400, 2736690, 43710, 43431886, 0.93, 16.64, 7.33, 0.0),
#  (126, 'nz', 'New Zealand', 267710, 267710, None, 4438393, 0.82, 13.33, 7.36, 2.21),
#  (146, 'st', 'Saint Lucia', 616, 606, 10, 163922, 0.34, 13.7, 7.42, 2.93),
#  (239, 'sh', 'Saint Helena, Ascension, and Tristan da Cunha', 308, 122, 0, 7795, 0.24, 9.88, 7.44, 0.0),
#  (56, 'er', 'Eritrea', 117600, 101000, 16600, 6527689, 2.25, 30.0, 7.52, 0.0),
#  (37, 'ch', 'China', 9596960, 9326410, 270550, 1367485388, 0.45, 12.49, 7.53, 0.44),
#  (39, 'cn', 'Comoros', 2235, 2235, 0, 780971, 1.77, 27.84, 7.57, 2.53),
#  (95, 'la', 'Laos', 236800, 230800, 6000, 6911544, 1.55, 24.25, 7.63, 1.09),
#  (165, 'su', 'Sudan', 1861484, None, None, 36108853, 1.72, 29.19, 7.66, 4.29),
#  (30, 'cb', 'Cambodia', 181035, 176515, 4520, 15708756, 1.58, 23.83, 7.68, 0.32),
#  (235, 'je', 'Jersey', 116, 116, 0, 97294, 0.8, 11.91, 7.68, 3.76),
#  (45, 'cu', 'Cuba', 110860, 109820, 1040, 11031433, 0.15, 9.9, 7.72, 3.66),
#  (49, 'dj', 'Djibouti', 23200, 23180, 20, 828324, 2.2, 23.65, 7.73, 6.06),
#  (173, 'th', 'Thailand', 513120, 510890, 2230, 67976405, 0.34, 11.19, 7.8, 0.0),
#  (261, 'xx', 'World', None, None, None, 7256490011, 1.08, 18.6, 7.8, None)]

# %%
# %%sql
#
# SELECT *
#     FROM facts
# WHERE death_rate > (SELECT AVG(death_rate) FROM facts)
# ORDER BY death_rate DESC;
# Out:
#  * sqlite:///factbook.db
# Done.
# [(98, 'lt', 'Lesotho', 30355, 30355, 0, 1947701, 0.32, 25.47, 14.89, 7.36),
#  (183, 'up', 'Ukraine', 603550, 579330, 24220, 44429471, 0.6, 10.72, 14.46, 2.25),
#  (26, 'bu', 'Bulgaria', 110879, 108489, 2390, 7186893, 0.58, 8.92, 14.44, 0.29),
#  (71, 'pu', 'Guinea-Bissau', 36125, 28120, 8005, 1726170, 1.91, 33.38, 14.33, 0.0),
#  (96, 'lg', 'Latvia', 64589, 62249, 2340, 1986705, 1.06, 10.0, 14.31, 6.26),
#  (35, 'cd', 'Chad', None, 1259200, 24800, 11631456, 1.89, 36.6, 14.28, 3.45),
#  (102, 'lh', 'Lithuania', 65300, 62680, 2620, 2884433, 1.04, 10.1, 14.27, 6.27),
#  (122, 'wa', 'Namibia', 824292, 823290, 1002, 2212307, 0.59, 19.8, 13.91, 0.0),
#  (1, 'af', 'Afghanistan', 652230, 652230, 0, 32564342, 2.32, 38.57, 13.89, 1.51),
#  (34, 'ct', 'Central African Republic', 622984, 622984, 0, 5391539, 2.13, 35.08, 13.8, 0.0),
#  (143, 'rs', 'Russia', 17098242, 16377742, 720500, 142423773, 0.04, 11.6, 13.69, 1.69),
#  (153, 'ri', 'Serbia', 77474, 77474, 0, 7176794, 0.46, 9.08, 13.66, 0.0),
#  (160, 'so', 'Somalia', 637657, 627337, 10320, 10616380, 1.83, 40.45, 13.62, 8.49),
#  (167, 'wz', 'Swaziland', 17364, 17204, 160, 1435613, 1.11, 24.67, 13.56, 0.0),
#  (23, 'bc', 'Botswana', 581730, 566730, 15000, 2182719, 1.21, 20.96, 13.39, 4.56),
#  (16, 'bo', 'Belarus', 207600, 202900, 4700, 9589689, 0.2, 10.7, 13.36, 0.7),
#  (62, 'gb', 'Gabon', 267667, 257667, 10000, 1705336, 1.93, 34.49, 13.12, 2.03),
#  (129, 'ni', 'Nigeria', 923768, 910768, 13000, 181562056, 2.45, 37.64, 12.9, 0.22),
#  (109, 'ml', 'Mali', 1240192, 1220190, 20002, 16955536, 2.98, 44.99, 12.89, 2.26),
#  (75, 'hu', 'Hungary', 93028, 89608, 3420, 9897541, 0.22, 9.16, 12.73, 1.33),
#  (194, 'za', 'Zambia', 752618, 743398, 9220, 15066266, 2.88, 42.13, 12.67, 0.68),
#  (116, 'md', 'Moldova', 33851, 32891, 960, 3546847, 1.03, 12.0, 12.59, 9.67),
#  (128, 'ng', 'Niger', None, 1266700, 300, 18045729, 3.25, 45.45, 12.42, 0.56),
#  (57, 'en', 'Estonia', 45228, 42388, 2840, 1265420, 0.55, 10.51, 12.4, 3.6),
#  (44, 'hr', 'Croatia', 56594, 55974, 620, 4464844, 0.13, 9.45, 12.18, 1.39),
#  (121, 'mz', 'Mozambique', 799380, 786380, 13000, 25303113, 2.45, 38.58, 12.1, 1.98),
#  (142, 'ro', 'Romania', 238391, 229891, 8500, 21666350, 0.3, 9.14, 11.9, 0.24),
#  (27, 'uv', 'Burkina Faso', 274200, 273800, 400, 18931686, 3.03, 42.03, 11.72, 0.0),
#  (5, 'ao', 'Angola', 1246700, 1246700, 0, 19625353, 2.78, 38.78, 11.49, 0.46),
#  (65, 'gm', 'Germany', 357022, 348672, 8350, 80854408, 0.17, 8.47, 11.42, 1.24),
#  (158, 'si', 'Slovenia', 20273, 20151, 122, 1983412, 0.26, 8.42, 11.37, 0.37),
#  (67, 'gr', 'Greece', 131957, 130647, 1310, 10775643, 0.01, 8.66, 11.09, 2.32),
#  (140, 'po', 'Portugal', 92090, 91470, 620, 10825309, 0.09, 9.27, 11.02, 2.67),
#  (64, 'gg', 'Georgia', 69700, 69700, 0, 4931226, 0.08, 12.74, 10.82, 2.7),
#  (155, 'sl', 'Sierra Leone', 71740, 71620, 120, 5879098, 2.35, 37.03, 10.81, 2.77),
#  (182, 'ug', 'Uganda', 241038, 197100, 43938, 37101745, 3.24, 43.79, 10.69, 0.74),
#  (47, 'ez', 'Czech Republic', 78867, 77247, 1620, 10644842, 0.16, 9.63, 10.34, 2.33),
#  (48, 'da', 'Denmark', 43094, 42434, 660, 5581503, 0.22, 10.27, 10.25, 2.2),
#  (197, 'ee', 'European Union', 4324782, None, None, 513949445, 0.25, 10.2, 10.2, 2.5),
#  (83, 'it', 'Italy', 301340, 294140, 7200, 61855120, 0.27, 8.74, 10.19, 4.1),
#  (139, 'pl', 'Poland', 312685, 304255, 8430, 38562189, 0.09, 9.74, 10.19, 0.46),
#  (195, 'zi', 'Zimbabwe', 390757, 386847, 3910, 14229541, 2.21, 32.26, 10.13, 0.0),
#  (31, 'cm', 'Cameroon', 475440, 472710, 2730, 23739218, 2.59, 36.17, 10.11, 0.15),
#  (40, 'cg', 'Congo, Democratic Republic of the', 2344858, 2267048, 77810, 79375136, 2.45, 34.88, 10.07, 0.27),
#  (236, 'im', 'Isle of Man', 572, 572, 0, 87545, 0.76, 11.1, 10.06, 6.56),
#  (41, 'cf', 'Congo, Republic of the', 342000, 341500, 500, 4755097, 2.0, 35.85, 10.0, 5.9),
#  (161, 'sf', 'South Africa', 1219090, 1214470, 4620, 53675563, 1.33, 20.75, 9.91, 2.42),
#  (60, 'fi', 'Finland', 338145, 303815, 34330, 5476922, 0.4, 10.72, 9.83, 3.1),
#  (22, 'bk', 'Bosnia and Herzegovina', 51197, 51187, 10, 3867055, 0.13, 8.87, 9.75, 0.38),
#  (157, 'lo', 'Slovakia', 49035, 48105, 930, 5445027, 0.02, 9.91, 9.74, 0.04),
#  (214, 'sb', 'Saint Pierre and Miquelon', 242, 242, 0, 5657, 1.08, 7.42, 9.72, 8.49),
#  (99, 'li', 'Liberia', 111369, 96320, 15049, 4195666, 2.47, 34.41, 9.69, 0.0),
#  (17, 'be', 'Belgium', 30528, 30278, 250, 11323973, 0.76, 11.41, 9.63, 5.87),
#  (43, 'iv', "Cote d'Ivoire", 322463, 318003, 4460, 23295302, 1.91, 28.67, 9.55, 0.0),
#  (85, 'ja', 'Japan', 377915, 364485, 13430, 126919659, 0.16, 7.93, 9.51, 0.0),
#  (70, 'gv', 'Guinea', 245857, 245717, 140, 11780162, 2.63, 35.74, 9.46, 0.0),
#  (187, 'uy', 'Uruguay', 176215, 175015, 1200, 3341893, 0.27, 13.07, 9.45, 0.9),
#  (119, 'mj', 'Montenegro', 13812, 13452, 360, 647073, 0.42, 10.42, 9.43, None),
#  (10, 'au', 'Austria', 83871, 82445, 1426, 8665550, 0.55, 9.41, 9.42, 5.56),
#  (168, 'sw', 'Sweden', 450295, 410335, 39960, 9801616, 0.8, 11.99, 9.4, 5.42),
#  (185, 'uk', 'United Kingdom', 243610, 241930, 1680, 64088222, 0.54, 12.17, 9.35, 2.54),
#  (8, 'am', 'Armenia', 29743, 28203, 1540, 3056382, 0.15, 13.61, 9.34, 5.8),
#  (29, 'by', 'Burundi', 27830, 25680, 2150, 10742276, 3.28, 42.01, 9.27, 0.0),
#  (117, 'mn', 'Monaco', 2, 2, 0, 30535, 0.12, 6.65, 9.24, 3.83),
#  (90, 'kn', 'Korea, North', 120538, 120408, 130, 24983205, 0.53, 14.52, 9.21, 0.04),
#  (61, 'fr', 'France', 643801, 640427, 3374, 66553766, 0.43, 12.38, 9.16, 1.09),
#  (110, 'mt', 'Malta', 316, 316, 0, 413965, 0.31, 10.18, 9.09, 1.98),
#  (104, 'mk', 'Macedonia', 25713, 25433, 280, 2096015, 0.2, 11.55, 9.08, 0.48),
#  (163, 'sp', 'Spain', 505370, 498980, 6390, 48146134, 0.89, 9.64, 9.04, 8.31),
#  (144, 'rw', 'Rwanda', 26338, 24668, 1670, 12661733, 2.56, 33.75, 8.96, 0.85),
#  (234, 'gk', 'Guernsey', 78, 78, 0, 66080, 0.34, 9.84, 8.78, 2.32),
#  (181, 'tv', 'Tuvalu', 26, 26, 0, 10869, 0.82, 23.74, 8.74, 6.81),
#  (206, 'fo', 'Faroe Islands', 1393, 1393, 0, 50196, 0.51, 13.77, 8.71, 0.0),
#  (246, 'rq', 'Puerto Rico', 13791, 8870, 4921, 3598357, 0.6, 10.86, 8.67, 8.15),
#  (125, 'nl', 'Netherlands', 41543, 33893, 7650, 16947904, 0.41, 10.83, 8.66, 1.95),
#  (177, 'td', 'Trinidad and Tobago', 5128, 5128, 0, 1222363, 0.13, 13.46, 8.56, 6.25),
#  (247, 'vq', 'Virgin Islands', 1910, 346, 1564, 103574, 0.59, 10.31, 8.54, 7.67),
#  (207, 'gl', 'Greenland', 2166086, 2166086, None, 57733, 0.0, 14.48, 8.49, 5.98),
#  (152, 'sg', 'Senegal', 196722, 192530, 4192, 13975834, 2.45, 34.52, 8.46, 1.59),
#  (149, 'sm', 'San Marino', 61, 61, 0, 33020, 0.82, 8.63, 8.45, 8.03),
#  (15, 'bb', 'Barbados', 430, 430, 0, 290604, 0.31, 11.87, 8.44, 0.3),
#  (32, 'ca', 'Canada', 9984670, 9093507, 891163, 35099836, 0.75, 10.28, 8.42, 5.66),
#  (106, 'mi', 'Malawi', 118484, 94080, 24404, 17964697, 3.32, 41.56, 8.41, 0.0),
#  (233, 'gi', 'Gibraltar', 6, 6, 0, 29258, 0.24, 14.08, 8.37, 3.28),
#  (255, 'wi', 'Western Sahara', 266000, 266000, 0, 570866, 2.82, 30.24, 8.34, None),
#  (227, 'bd', 'Bermuda', 54, 54, 0, 70196, 0.5, 11.33, 8.23, 1.88),
#  (19, 'bn', 'Benin', 112622, 110622, 2000, 10448647, 2.78, 36.02, 8.21, 0.0),
#  (87, 'kz', 'Kazakhstan', 2724900, 2699700, 25200, 18157122, 1.14, 19.15, 8.21, 0.41),
#  (112, 'mr', 'Mauritania', 1030700, 1030700, 0, 3596702, 2.23, 31.34, 8.2, 0.83),
#  (217, 'cc', 'Curacao', 444, 444, 0, 148406, 0.43, 13.8, 8.2, 1.4),
#  (55, 'ek', 'Equatorial Guinea', 28051, 28051, 0, 740743, 2.51, 33.31, 8.19, 0.0),
#  (58, 'et', 'Ethiopia', 1104300, None, 104300, 99465819, 2.89, 37.27, 8.19, 0.22),
#  (162, 'od', 'South Sudan', 644329, None, None, 12042910, 4.02, 36.91, 8.18, 11.47),
#  (216, 'aa', 'Aruba', 180, 180, 0, 112162, 1.33, 12.56, 8.18, 8.92),
#  (186, 'us', 'United States', 9826675, 9161966, 664709, 321368864, 0.78, 12.49, 8.15, 3.86),
#  (169, 'sz', 'Switzerland', 41277, 39997, 1280, 8121830, 0.71, 10.5, 8.13, 4.74),
#  (130, 'no', 'Norway', 323802, 304282, 19520, 5207689, 1.13, 12.14, 8.12, 7.25),
#  (68, 'gj', 'Grenada', 344, 344, 0, 110694, 0.48, 16.03, 8.08, 3.13),
#  (219, 'cw', 'Cook Islands', 236, 236, 0, 9838, 2.95, 14.33, 8.03, None),
#  (172, 'tz', 'Tanzania', 947300, 885800, 61500, 51045882, 2.79, 36.39, 8.0, 0.54),
#  (133, 'ps', 'Palau', 459, 459, 0, 21265, 0.38, 11.05, 7.99, 0.71),
#  (28, 'bm', 'Burma', 676578, 653508, 23070, 56320206, 1.01, 18.39, 7.96, 0.28),
#  (50, 'do', 'Dominica', 751, 751, 0, 73607, 0.21, 15.41, 7.91, 5.38),
#  (73, 'ha', 'Haiti', 27750, 27560, 190, 10110019, 1.17, 22.31, 7.83, 2.76)]

# %% [markdown]
# These are certainly intriguing statistics -- I'd not have guessed this order.
#
# Now, for greater detail let's see the percentiles:

# %%
# %%sql
#
# SELECT name 'Country',
#     death_rate 'Death Rate',
#     ROUND(PERCENT_RANK() OVER( ORDER BY death_rate ), 2) AS 'Percent Rank'
# FROM facts
# WHERE death_rate <> 'None';
# Out:
#  * sqlite:///factbook.db
# Done.
# [('Qatar', 1.53, 0.0),
#  ('United Arab Emirates', 1.97, 0.0),
#  ('Kuwait', 2.18, 0.01),
#  ('Bahrain', 2.69, 0.01),
#  ('Gaza Strip', 3.04, 0.02),
#  ('Turks and Caicos Islands', 3.1, 0.02),
#  ('Saudi Arabia', 3.33, 0.03),
#  ('Oman', 3.36, 0.03),
#  ('Singapore', 3.43, 0.04),
#  ('West Bank', 3.5, 0.04),
#  ('Brunei', 3.52, 0.04),
#  ('Libya', 3.58, 0.05),
#  ('Northern Mariana Islands', 3.71, 0.05),
#  ('Iraq', 3.77, 0.06),
#  ('Jordan', 3.79, 0.06),
#  ('Solomon Islands', 3.85, 0.07),
#  ('Maldives', 3.89, 0.07),
#  ('Syria', 4.0, 0.07),
#  ('Vanuatu', 4.09, 0.08),
#  ('Marshall Islands', 4.21, 0.08),
#  ('Macau', 4.22, 0.09),
#  ('Micronesia, Federated States of', 4.23, 0.09),
#  ('Algeria', 4.31, 0.1),
#  ('Sint Maarten', 4.51, 0.1),
#  ('Costa Rica', 4.55, 0.11),
#  ('Dominican Republic', 4.55, 0.11),
#  ('Anguilla', 4.57, 0.11),
#  ('Paraguay', 4.68, 0.12),
#  ('American Samoa', 4.75, 0.12),
#  ('Egypt', 4.77, 0.13),
#  ('Guatemala', 4.77, 0.13),
#  ('Morocco', 4.81, 0.14),
#  ('Panama', 4.81, 0.14),
#  ('Tonga', 4.85, 0.15),
#  ('Lebanon', 4.88, 0.15),
#  ('Falkland Islands (Islas Malvinas)', 4.9, 0.15),
#  ('British Virgin Islands', 4.99, 0.16),
#  ('French Polynesia', 5.02, 0.16),
#  ('Malaysia', 5.03, 0.17),
#  ('Ecuador', 5.06, 0.17),
#  ('Wallis and Futuna', 5.06, 0.17),
#  ('Nicaragua', 5.08, 0.18),
#  ('Guam', 5.12, 0.19),
#  ('Israel', 5.15, 0.19),
#  ('Honduras', 5.17, 0.19),
#  ('Mexico', 5.26, 0.2),
#  ('Uzbekistan', 5.3, 0.2),
#  ('Venezuela', 5.31, 0.21),
#  ('Samoa', 5.32, 0.21),
#  ('Colombia', 5.4, 0.22),
#  ('New Caledonia', 5.52, 0.22),
#  ('Cayman Islands', 5.53, 0.22),
#  ('Bangladesh', 5.61, 0.23),
#  ('Antigua and Barbuda', 5.69, 0.23),
#  ('El Salvador', 5.69, 0.23),
#  ('Nauru', 5.87, 0.24),
#  ('Turkey', 5.88, 0.25),
#  ('Vietnam', 5.93, 0.25),
#  ('Iran', 5.94, 0.26),
#  ('Belize', 5.97, 0.26),
#  ('Tunisia', 5.98, 0.26),
#  ('Chile', 6.0, 0.27),
#  ('Peru', 6.01, 0.27),
#  ('Fiji', 6.04, 0.28),
#  ('Timor-Leste', 6.1, 0.28),
#  ('Cabo Verde', 6.11, 0.29),
#  ('Philippines', 6.11, 0.29),
#  ('Sri Lanka', 6.11, 0.29),
#  ('Suriname', 6.13, 0.3),
#  ('Turkmenistan', 6.13, 0.3),
#  ('Tajikistan', 6.18, 0.31),
#  ('Iceland', 6.28, 0.31),
#  ('Yemen', 6.28, 0.31),
#  ('Montserrat', 6.3, 0.32),
#  ('Mongolia', 6.35, 0.33),
#  ('Indonesia', 6.37, 0.33),
#  ('Ireland', 6.48, 0.33),
#  ('Pakistan', 6.49, 0.34),
#  ('Bolivia', 6.52, 0.34),
#  ('Papua New Guinea', 6.53, 0.35),
#  ('Nepal', 6.56, 0.35),
#  ('Albania', 6.58, 0.36),
#  ('Brazil', 6.58, 0.36),
#  ('Cyprus', 6.62, 0.37),
#  ('Kyrgyzstan', 6.65, 0.37),
#  ('Bhutan', 6.69, 0.37),
#  ('Jamaica', 6.7, 0.38),
#  ('Korea, South', 6.75, 0.38),
#  ('Madagascar', 6.81, 0.39),
#  ('Kenya', 6.89, 0.39),
#  ('Seychelles', 6.89, 0.39),
#  ('Mauritius', 6.91, 0.4),
#  ('Andorra', 6.96, 0.41),
#  ('Bahamas, The', 7.05, 0.41),
#  ('Azerbaijan', 7.07, 0.41),
#  ('Hong Kong', 7.07, 0.41),
#  ('Saint Kitts and Nevis', 7.09, 0.42),
#  ('Taiwan', 7.11, 0.43),
#  ('Kiribati', 7.12, 0.43),
#  ('Liechtenstein', 7.12, 0.43),
#  ('Australia', 7.14, 0.44),
#  ('Gambia, The', 7.15, 0.44),
#  ('Saint Vincent and the Grenadines', 7.18, 0.45),
#  ('Ghana', 7.22, 0.45),
#  ('Luxembourg', 7.24, 0.46),
#  ('Sao Tome and Principe', 7.24, 0.46),
#  ('Togo', 7.26, 0.47),
#  ('Guyana', 7.32, 0.47),
#  ('India', 7.32, 0.47),
#  ('Argentina', 7.33, 0.48),
#  ('New Zealand', 7.36, 0.48),
#  ('Saint Lucia', 7.42, 0.49),
#  ('Saint Helena, Ascension, and Tristan da Cunha', 7.44, 0.49),
#  ('Eritrea', 7.52, 0.5),
#  ('China', 7.53, 0.5),
#  ('Comoros', 7.57, 0.51),
#  ('Laos', 7.63, 0.51),
#  ('Sudan', 7.66, 0.52),
#  ('Cambodia', 7.68, 0.52),
#  ('Jersey', 7.68, 0.52),
#  ('Cuba', 7.72, 0.53),
#  ('Djibouti', 7.73, 0.53),
#  ('Thailand', 7.8, 0.54),
#  ('World', 7.8, 0.54),
#  ('Haiti', 7.83, 0.55),
#  ('Dominica', 7.91, 0.55),
#  ('Burma', 7.96, 0.56),
#  ('Palau', 7.99, 0.56),
#  ('Tanzania', 8.0, 0.56),
#  ('Cook Islands', 8.03, 0.57),
#  ('Grenada', 8.08, 0.57),
#  ('Norway', 8.12, 0.58),
#  ('Switzerland', 8.13, 0.58),
#  ('United States', 8.15, 0.59),
#  ('South Sudan', 8.18, 0.59),
#  ('Aruba', 8.18, 0.59),
#  ('Equatorial Guinea', 8.19, 0.6),
#  ('Ethiopia', 8.19, 0.6),
#  ('Mauritania', 8.2, 0.61),
#  ('Curacao', 8.2, 0.61),
#  ('Benin', 8.21, 0.62),
#  ('Kazakhstan', 8.21, 0.62),
#  ('Bermuda', 8.23, 0.63),
#  ('Western Sahara', 8.34, 0.63),
#  ('Gibraltar', 8.37, 0.63),
#  ('Malawi', 8.41, 0.64),
#  ('Canada', 8.42, 0.64),
#  ('Barbados', 8.44, 0.65),
#  ('San Marino', 8.45, 0.65),
#  ('Senegal', 8.46, 0.66),
#  ('Greenland', 8.49, 0.66),
#  ('Virgin Islands', 8.54, 0.67),
#  ('Trinidad and Tobago', 8.56, 0.67),
#  ('Netherlands', 8.66, 0.67),
#  ('Puerto Rico', 8.67, 0.68),
#  ('Faroe Islands', 8.71, 0.68),
#  ('Tuvalu', 8.74, 0.69),
#  ('Guernsey', 8.78, 0.69),
#  ('Rwanda', 8.96, 0.7),
#  ('Spain', 9.04, 0.7),
#  ('Macedonia', 9.08, 0.7),
#  ('Malta', 9.09, 0.71),
#  ('France', 9.16, 0.71),
#  ('Korea, North', 9.21, 0.72),
#  ('Monaco', 9.24, 0.72),
#  ('Burundi', 9.27, 0.73),
#  ('Armenia', 9.34, 0.73),
#  ('United Kingdom', 9.35, 0.74),
#  ('Sweden', 9.4, 0.74),
#  ('Austria', 9.42, 0.74),
#  ('Montenegro', 9.43, 0.75),
#  ('Uruguay', 9.45, 0.75),
#  ('Guinea', 9.46, 0.76),
#  ('Japan', 9.51, 0.76),
#  ("Cote d'Ivoire", 9.55, 0.77),
#  ('Belgium', 9.63, 0.77),
#  ('Liberia', 9.69, 0.78),
#  ('Saint Pierre and Miquelon', 9.72, 0.78),
#  ('Slovakia', 9.74, 0.78),
#  ('Bosnia and Herzegovina', 9.75, 0.79),
#  ('Finland', 9.83, 0.79),
#  ('South Africa', 9.91, 0.8),
#  ('Congo, Republic of the', 10.0, 0.8),
#  ('Isle of Man', 10.06, 0.81),
#  ('Congo, Democratic Republic of the', 10.07, 0.81),
#  ('Cameroon', 10.11, 0.81),
#  ('Zimbabwe', 10.13, 0.82),
#  ('Italy', 10.19, 0.82),
#  ('Poland', 10.19, 0.82),
#  ('European Union', 10.2, 0.83),
#  ('Denmark', 10.25, 0.84),
#  ('Czech Republic', 10.34, 0.84),
#  ('Uganda', 10.69, 0.85),
#  ('Sierra Leone', 10.81, 0.85),
#  ('Georgia', 10.82, 0.85),
#  ('Portugal', 11.02, 0.86),
#  ('Greece', 11.09, 0.86),
#  ('Slovenia', 11.37, 0.87),
#  ('Germany', 11.42, 0.87),
#  ('Angola', 11.49, 0.88),
#  ('Burkina Faso', 11.72, 0.88),
#  ('Romania', 11.9, 0.89),
#  ('Mozambique', 12.1, 0.89),
#  ('Croatia', 12.18, 0.89),
#  ('Estonia', 12.4, 0.9),
#  ('Niger', 12.42, 0.9),
#  ('Moldova', 12.59, 0.91),
#  ('Zambia', 12.67, 0.91),
#  ('Hungary', 12.73, 0.92),
#  ('Mali', 12.89, 0.92),
#  ('Nigeria', 12.9, 0.93),
#  ('Gabon', 13.12, 0.93),
#  ('Belarus', 13.36, 0.93),
#  ('Botswana', 13.39, 0.94),
#  ('Swaziland', 13.56, 0.94),
#  ('Somalia', 13.62, 0.95),
#  ('Serbia', 13.66, 0.95),
#  ('Russia', 13.69, 0.96),
#  ('Central African Republic', 13.8, 0.96),
#  ('Afghanistan', 13.89, 0.96),
#  ('Namibia', 13.91, 0.97),
#  ('Lithuania', 14.27, 0.97),
#  ('Chad', 14.28, 0.98),
#  ('Latvia', 14.31, 0.98),
#  ('Guinea-Bissau', 14.33, 0.99),
#  ('Bulgaria', 14.44, 0.99),
#  ('Ukraine', 14.46, 1.0),
#  ('Lesotho', 14.89, 1.0)]

# %% [markdown]
# The list below are countries that have a higher death rate than a birth rate.

# %%
# %%sql
#
# SELECT name Country, birth_rate 'Birth Rate', death_rate 'Death Rate'
#     FROM facts
# WHERE death_rate > birth_rate
# ORDER BY death_rate DESC;
# Out:
#  * sqlite:///factbook.db
# Done.
# [('Ukraine', 10.72, 14.46),
#  ('Bulgaria', 8.92, 14.44),
#  ('Latvia', 10.0, 14.31),
#  ('Lithuania', 10.1, 14.27),
#  ('Russia', 11.6, 13.69),
#  ('Serbia', 9.08, 13.66),
#  ('Belarus', 10.7, 13.36),
#  ('Hungary', 9.16, 12.73),
#  ('Moldova', 12.0, 12.59),
#  ('Estonia', 10.51, 12.4),
#  ('Croatia', 9.45, 12.18),
#  ('Romania', 9.14, 11.9),
#  ('Germany', 8.47, 11.42),
#  ('Slovenia', 8.42, 11.37),
#  ('Greece', 8.66, 11.09),
#  ('Portugal', 9.27, 11.02),
#  ('Czech Republic', 9.63, 10.34),
#  ('Italy', 8.74, 10.19),
#  ('Poland', 9.74, 10.19),
#  ('Bosnia and Herzegovina', 8.87, 9.75),
#  ('Saint Pierre and Miquelon', 7.42, 9.72),
#  ('Japan', 7.93, 9.51),
#  ('Austria', 9.41, 9.42),
#  ('Monaco', 6.65, 9.24)]

# %% [markdown]
# ## Density
#
# Finally, for this initial exploration let's see the most densely populated countries.

# %%
# %%sql
#
# SELECT name Country, ROUND(CAST(population AS Float)/CAST(area AS Float),2) Density
#     FROM facts
# WHERE Density <> 'None'
# ORDER BY Density DESC;
# Out:
#  * sqlite:///factbook.db
# Done.
# [('Macau', 21168.96),
#  ('Monaco', 15267.5),
#  ('Singapore', 8141.28),
#  ('Hong Kong', 6445.04),
#  ('Gaza Strip', 5191.82),
#  ('Gibraltar', 4876.33),
#  ('Bahrain', 1771.86),
#  ('Maldives', 1319.64),
#  ('Malta', 1310.02),
#  ('Bermuda', 1299.93),
#  ('Sint Maarten', 1167.32),
#  ('Bangladesh', 1138.07),
#  ('Guernsey', 847.18),
#  ('Jersey', 838.74),
#  ('Barbados', 675.82),
#  ('Mauritius', 656.78),
#  ('Taiwan', 650.78),
#  ('Aruba', 623.12),
#  ('Lebanon', 594.68),
#  ('Saint Martin', 588.04),
#  ('San Marino', 541.31),
#  ('Korea, South', 492.53),
#  ('Rwanda', 480.74),
#  ('West Bank', 475.32),
#  ('Nauru', 454.29),
#  ('Tuvalu', 418.04),
#  ('Netherlands', 407.96),
#  ('Marshall Islands', 398.85),
#  ('Israel', 387.55),
#  ('Burundi', 386.0),
#  ('India', 380.77),
#  ('Belgium', 370.94),
#  ('Haiti', 364.33),
#  ('Comoros', 349.43),
#  ('Philippines', 336.66),
#  ('Sri Lanka', 336.13),
#  ('Japan', 335.84),
#  ('Curacao', 334.25),
#  ('Grenada', 321.78),
#  ('Guam', 297.4),
#  ('El Salvador', 291.88),
#  ('Vietnam', 284.86),
#  ('American Samoa', 273.08),
#  ('Jamaica', 268.42),
#  ('Saint Lucia', 266.11),
#  ('Saint Vincent and the Grenadines', 263.82),
#  ('United Kingdom', 263.08),
#  ('Puerto Rico', 260.92),
#  ('Pakistan', 250.08),
#  ('Trinidad and Tobago', 238.37),
#  ('Liechtenstein', 235.15),
#  ('Germany', 226.47),
#  ('British Virgin Islands', 221.55),
#  ('Luxembourg', 220.52),
#  ('Dominican Republic', 215.3),
#  ('Nepal', 214.37),
#  ('Cayman Islands', 212.47),
#  ('Antigua and Barbuda', 209.13),
#  ('Korea, North', 207.26),
#  ('Italy', 205.27),
#  ('Seychelles', 203.14),
#  ('Sao Tome and Principe', 201.25),
#  ('Saint Kitts and Nevis', 198.99),
#  ('Switzerland', 196.76),
#  ('Nigeria', 196.55),
#  ('Qatar', 189.44),
#  ('Andorra', 182.86),
#  ('Anguilla', 180.42),
#  ('Gambia, The', 174.13),
#  ('Kosovo', 171.85),
#  ('Kuwait', 156.5),
#  ('Uganda', 153.92),
#  ('Isle of Man', 153.05),
#  ('Malawi', 151.62),
#  ('Micronesia, Federated States of', 149.88),
#  ('Tonga', 142.57),
#  ('China', 142.49),
#  ('Guatemala', 137.01),
#  ('Cabo Verde', 135.38),
#  ('Czech Republic', 134.97),
#  ('Indonesia', 134.41),
#  ('Togo', 133.0),
#  ('Thailand', 132.48),
#  ('Kiribati', 130.35),
#  ('Denmark', 129.52),
#  ('Cyprus', 128.55),
#  ('Akrotiri', 127.64),
#  ('Poland', 123.33),
#  ('Dhekelia', 120.77),
#  ('European Union', 118.84),
#  ('Portugal', 117.55),
#  ('Azerbaijan', 112.94),
#  ('Northern Mariana Islands', 112.81),
#  ('Tokelau', 111.42),
#  ('Slovakia', 111.04),
#  ('Ghana', 110.37),
#  ('Wallis and Futuna', 109.95),
#  ('Hungary', 106.39),
#  ('Albania', 105.37),
#  ('Moldova', 104.78),
#  ('France', 103.38),
#  ('Austria', 103.32),
#  ('Armenia', 102.76),
#  ('Turkey', 101.35),
#  ('Cuba', 99.51),
#  ('Dominica', 98.01),
#  ('Slovenia', 97.84),
#  ('Spain', 95.27),
#  ('Costa Rica', 94.21),
#  ('Benin', 92.78),
#  ('Serbia', 92.63),
#  ('Malaysia', 92.51),
#  ('Syria', 92.15),
#  ('Romania', 90.89),
#  ('Jordan', 90.86),
#  ('Ethiopia', 90.07),
#  ('Egypt', 88.36),
#  ('Cambodia', 86.77),
#  ('Iraq', 84.54),
#  ('Burma', 83.24),
#  ('Timor-Leste', 82.77),
#  ('Swaziland', 82.68),
#  ('Sierra Leone', 81.95),
#  ('Greece', 81.66),
#  ('Macedonia', 81.52),
#  ('Kenya', 79.13),
#  ('Croatia', 78.89),
#  ('Honduras', 78.03),
#  ('Bosnia and Herzegovina', 75.53),
#  ('Morocco', 74.62),
#  ('Brunei', 74.53),
#  ('Ukraine', 73.61),
#  ("Cote d'Ivoire", 72.24),
#  ('Senegal', 71.04),
#  ('Georgia', 70.75),
#  ('Samoa', 69.86),
#  ('Ireland', 69.62),
#  ('United Arab Emirates', 69.14),
#  ('Burkina Faso', 69.04),
#  ('French Polynesia', 67.84),
#  ('Tunisia', 67.46),
#  ('Uzbekistan', 65.27),
#  ('Bulgaria', 64.82),
#  ('Lesotho', 64.16),
#  ('Mexico', 61.97),
#  ('Norfolk Island', 61.39),
#  ('Tajikistan', 56.85),
#  ('Ecuador', 55.96),
#  ('Eritrea', 55.51),
#  ('Virgin Islands', 54.23),
#  ('Tanzania', 53.89),
#  ('Turks and Caicos Islands', 53.04),
#  ('Montserrat', 51.38),
#  ('Yemen', 50.64),
#  ('Afghanistan', 49.93),
#  ('Cameroon', 49.93),
#  ('Fiji', 49.76),
#  ('Iran', 49.64),
#  ('Panama', 48.49),
#  ('Guinea', 47.91),
#  ('Guinea-Bissau', 47.78),
#  ('Montenegro', 46.85),
#  ('Palau', 46.33),
#  ('Belarus', 46.19),
#  ('Nicaragua', 45.32),
#  ('Lithuania', 44.17),
#  ('South Africa', 44.03),
#  ('Cocos (Keeling) Islands', 42.57),
#  ('Cook Islands', 41.69),
#  ('Colombia', 41.04),
#  ('Madagascar', 40.56),
#  ('Liberia', 37.67),
#  ('Zimbabwe', 36.42),
#  ('Faroe Islands', 36.03),
#  ('Djibouti', 35.7),
#  ('Congo, Democratic Republic of the', 33.85),
#  ('United States', 32.7),
#  ('Venezuela', 32.1),
#  ('Mozambique', 31.65),
#  ('Latvia', 30.76),
#  ('Laos', 29.19),
#  ('Kyrgyzstan', 28.33),
#  ('Estonia', 27.98),
#  ('Equatorial Guinea', 26.41),
#  ('Saint Helena, Ascension, and Tristan da Cunha', 25.31),
#  ('Brazil', 23.99),
#  ('Peru', 23.69),
#  ('Bahamas, The', 23.39),
#  ('Saint Pierre and Miquelon', 23.38),
#  ('Chile', 23.16),
#  ('Vanuatu', 22.34),
#  ('Sweden', 21.77),
#  ('Solomon Islands', 21.54),
#  ('Zambia', 20.02),
#  ('Sudan', 19.4),
#  ('Bhutan', 19.32),
#  ('Uruguay', 18.96),
#  ('South Sudan', 18.69),
#  ('Paraguay', 16.68),
#  ('Somalia', 16.65),
#  ('Algeria', 16.6),
#  ('New Zealand', 16.58),
#  ('Finland', 16.2),
#  ('Norway', 16.08),
#  ('Angola', 15.74),
#  ('Argentina', 15.62),
#  ('Belize', 15.13),
#  ('New Caledonia', 14.62),
#  ('Papua New Guinea', 14.42),
#  ('Congo, Republic of the', 13.9),
#  ('Mali', 13.67),
#  ('Saudi Arabia', 12.91),
#  ('Christmas Island', 11.33),
#  ('Turkmenistan', 10.72),
#  ('Oman', 10.62),
#  ('Bolivia', 9.83),
#  ('Central African Republic', 8.65),
#  ('Russia', 8.33),
#  ('Kazakhstan', 6.66),
#  ('Gabon', 6.37),
#  ('Niue', 4.58),
#  ('Botswana', 3.75),
#  ('Libya', 3.64),
#  ('Suriname', 3.54),
#  ('Canada', 3.52),
#  ('Mauritania', 3.49),
#  ('Guyana', 3.42),
#  ('Iceland', 3.22),
#  ('Australia', 2.94),
#  ('Namibia', 2.68),
#  ('Western Sahara', 2.15),
#  ('Mongolia', 1.91),
#  ('Pitcairn Islands', 1.02),
#  ('Falkland Islands (Islas Malvinas)', 0.28),
#  ('Greenland', 0.03),
#  ('Svalbard', 0.03)]

# %% [markdown]
# But to better grasp this information let's calculate the avarage density:

# %%
# %%sql
#
# SELECT AVG(CAST(population AS Float)/CAST(area AS Float)) 'Avarage Density'
#     FROM facts;
# Out:
#  * sqlite:///factbook.db
# Done.
# [(419.66252469247945,)]

# %% [markdown]
# We can see clearly, just from the above, that the density is highly rightly skewed. That is, there are few countries with very high density that elevates the mean; but, really, the majority are below the mean.

# %%
# %%sql
#
# SELECT COUNT(*) 'Countries with density below or avarage'
#     FROM facts
# WHERE CAST(population AS Float)/CAST(area AS Float) <= (SELECT AVG(CAST(population AS Float)/CAST(area AS Float)) FROM facts);
# Out:
#  * sqlite:///factbook.db
# Done.
# [(211,)]

# %%
# %%sql
#
# SELECT COUNT(*) 'Countries with density above avarage'
#     FROM facts
# WHERE CAST(population AS Float)/CAST(area AS Float) > (SELECT AVG(CAST(population AS Float)/CAST(area AS Float)) FROM facts);
# Out:
#  * sqlite:///factbook.db
# Done.
# [(25,)]

# %% [markdown]
# In fact, we see the countries below avarage are ten times more numerous than the above avarage.
